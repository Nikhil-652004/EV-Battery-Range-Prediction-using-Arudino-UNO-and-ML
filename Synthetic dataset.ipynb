# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/IoT_Project
# Out:
# /content/drive/MyDrive/IoT_Project

# %%
import numpy as np
import pandas as pd
from numpy import random

# Set a random seed for reproducibility
np.random.seed(22)

# Generate a synthetic dataset with 10,000 samples
num_samples = 10000

# Realistic ranges for features based on EV battery specifications under load
current_range = (50, 200)  # Amps
voltage_range = (300, 450)  # Volts
speed_range = (20, 150)  # km/h
temperature_range = (20, 50)  # Celsius
soc_range=(0,100) #percentage

# Generate random values within the specified ranges
current = np.random.uniform(low=current_range[0], high=current_range[1], size=num_samples)
voltage = np.random.uniform(low=voltage_range[0], high=voltage_range[1], size=num_samples)
speed = np.random.uniform(low=speed_range[0], high=speed_range[1], size=num_samples)
temperature = np.random.uniform(low=temperature_range[0], high=temperature_range[1], size=num_samples)
soc_generated = np.random.uniform(low=soc_range[0], high=soc_range[1], size=num_samples)
soc= [np.round(x) for x in soc_generated]

# Simulate a relationship for range
range_coefficients = {'Current': -0.2, 'Voltage': 0.5, 'Speed': 0.1, 'Temperature': -0.05}
range_intercept = 150
range_ = range_intercept + np.sum(np.array([range_coefficients[key] * df[key] for key in range_coefficients.keys()]), axis=0) + np.random.normal(scale=10, size=num_samples)

# Clip range to ensure it's non-negative
range_ = np.clip(range_, 0, None)

remaining_range= (soc * range_)/100

# Create a DataFrame
df = pd.DataFrame({'Current': current, 'Voltage': voltage, 'Speed': speed, 'Temperature': temperature,'Range': range_, 'SOC': soc,'Remaining range': remaining_range})

# Save the synthetic dataset to a CSV file in Google Colab
df.to_csv('/content/synthetic_ev_dataset_accurate.csv', index=False)

# Save the synthetic dataset to a CSV file in Google Colab
df.to_csv('/content/drive/MyDrive/IoT_Project/synthetic_ev_dataset_accurate.csv', index=False)

# %%
from google.colab import files

# Download the CSV file to your local machine
files.download('/content/drive/MyDrive/IoT_Project/synthetic_ev_dataset_accurate.csv')
